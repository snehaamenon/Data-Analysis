# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_excel("HIV1.xlsx")

# %%
df.head()
# Out:
#                     Number of new HIV infections  \
# WHO region Year
# Global     2019  1 700 000 [1 200 000–2 200 000]
#            2018  1 700 000 [1 200 000–2 300 000]
#            2017  1 800 000 [1 300 000–2 400 000]
#            2016  1 800 000 [1 300 000–2 400 000]
#
#                 New HIV infections (per 1000 uninfected population)  \
# WHO region Year                                         Both sexes
# Global     2019                                    0.22 [0.16–0.3]
#            2018                                   0.23 [0.17–0.31]
#            2017                                   0.24 [0.18–0.32]
#            2016                                   0.25 [0.18–0.34]
#
#                 New HIV infections (per 1000 uninfected population).1  \
# WHO region Year                                               Male
# Global     2019                                   0.23 [0.17–0.32]
#            2018                                   0.24 [0.17–0.33]
# ...

# %%
df['Number of new HIV infections'] = df['Number of new HIV infections'].str.replace(r"\[.*\]","")

# %%
df['New HIV infections (per 1000 uninfected population)'] = df['New HIV infections (per 1000 uninfected population)'].str.replace(r"\[.*\]","")

# %%
df['New HIV infections (per 1000 uninfected population).1'] = df['New HIV infections (per 1000 uninfected population).1'].str.replace(r"\[.*\]","")

# %%
df['New HIV infections (per 1000 uninfected population).2'] = df['New HIV infections (per 1000 uninfected population).2'].str.replace(r"\[.*\]","")

# %%
df.head()
# Out:
#                 Number of new HIV infections  \
# WHO region Year
# Global     2019                   1 700 000
#            2018                   1 700 000
#            2017                   1 800 000
#            2016                   1 800 000
#
#                 New HIV infections (per 1000 uninfected population)  \
# WHO region Year                                         Both sexes
# Global     2019                                              0.22
#            2018                                              0.23
#            2017                                              0.24
#            2016                                              0.25
#
#                 New HIV infections (per 1000 uninfected population).1  \
# WHO region Year                                               Male
# Global     2019                                              0.23
#            2018                                              0.24
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 211 entries, (WHO region, Year) to (Western Pacific, 1990)
# Data columns (total 4 columns):
# Number of new HIV infections                             211 non-null object
# New HIV infections (per 1000 uninfected population)      211 non-null object
# New HIV infections (per 1000 uninfected population).1    211 non-null object
# New HIV infections (per 1000 uninfected population).2    211 non-null object
# dtypes: object(4)
# memory usage: 7.7+ KB

# %%
df['Number of new HIV infections']=df['Number of new HIV infections'].str.replace(" ","")

# %%
df.head()
# Out:
#                 Number of new HIV infections  \
# WHO region Year
# Global     2019                      1700000
#            2018                      1700000
#            2017                      1800000
#            2016                      1800000
#
#                 New HIV infections (per 1000 uninfected population)  \
# WHO region Year                                         Both sexes
# Global     2019                                              0.22
#            2018                                              0.23
#            2017                                              0.24
#            2016                                              0.25
#
#                 New HIV infections (per 1000 uninfected population).1  \
# WHO region Year                                               Male
# Global     2019                                              0.23
#            2018                                              0.24
# ...

# %%
df["Number of new HIV infections"] = pd.to_numeric(df["Number of new HIV infections"], downcast="float")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 211 entries, (WHO region, Year) to (Western Pacific, 1990)
# Data columns (total 4 columns):
# Number of new HIV infections                             210 non-null float32
# New HIV infections (per 1000 uninfected population)      211 non-null object
# New HIV infections (per 1000 uninfected population).1    211 non-null object
# New HIV infections (per 1000 uninfected population).2    211 non-null object
# dtypes: float32(1), object(3)
# memory usage: 6.8+ KB

# %%
df2=pd.read_excel("HIV2.xlsx")

# %%
df2
# Out:
#               REGION  YEAR PEOPLE HAVING HIV
# 0             Global  2019       38 000 000
# 1             Global  2018        37 300 000
# 2             Global  2017        36 500 000
# 3             Global  2016        35 700 000
# 4             Global  2015       34 900 000
# 5             Global  2014       34 100 000
# 6             Global  2013       33 200 000
# 7             Global  2012       32 400 000
# 8             Global  2011       31 600 000
# 9             Global  2010       30 700 000
# 10            Global  2009       29 900 000
# 11            Global  2008       29 100 000
# 12            Global  2007        28 400 000
# 13            Global  2006       27 800 000
# 14            Global  2005       27 300 000
# 15            Global  2004       26 800 000
# 16            Global  2003        26 300 000
# 17            Global  2002       25 700 000
# 18            Global  2001        24 900 000
# 19            Global  2000       24 000 000
# ...

# %%
df2['PEOPLE HAVING HIV']=df2['PEOPLE HAVING HIV'].str.replace(" ","")

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 3 columns):
# REGION               210 non-null object
# YEAR                 210 non-null int64
# PEOPLE HAVING HIV    210 non-null object
# dtypes: int64(1), object(2)
# memory usage: 5.0+ KB

# %%
df2["PEOPLE HAVING HIV"] = pd.to_numeric(df2["PEOPLE HAVING HIV"], downcast="float")

# %%
df2.head()
# Out:
#    REGION  YEAR  PEOPLE HAVING HIV
# 0  Global  2019         38000000.0
# 1  Global  2018         37300000.0
# 2  Global  2017         36500000.0
# 3  Global  2016         35700000.0
# 4  Global  2015         34900000.0

# %%
df3=pd.read_excel("HIV.xlsx")

# %%
df3
# Out:
#           WHO region  Year Number of deaths due to HIV/AIDS
# 0             Global  2019        690 000 [500 000–970 000]
# 1             Global  2018      730 000 [530 000–1 000 000]
# 2             Global  2017      760 000 [550 000–1 100 000]
# 3             Global  2016      800 000 [580 000–1 100 000]
# 4             Global  2015      830 000 [610 000–1 200 000]
# 5             Global  2014      870 000 [640 000–1 200 000]
# 6             Global  2013      930 000 [680 000–1 300 000]
# 7             Global  2012    1 000 000 [730 000–1 400 000]
# 8             Global  2011    1 100 000 [780 000–1 500 000]
# 9             Global  2010    1 100 000 [830 000–1 600 000]
# 10            Global  2009    1 200 000 [890 000–1 700 000]
# 11            Global  2008    1 400 000 [980 000–1 900 000]
# 12            Global  2007  1 500 000 [1 100 000–2 100 000]
# 13            Global  2006  1 600 000 [1 200 000–2 300 000]
# 14            Global  2005  1 700 000 [1 200 000–2 400 000]
# ...

# %%
df3['Number of deaths due to HIV/AIDS']=df3['Number of deaths due to HIV/AIDS'].str.replace(r"\[.*\]","")

# %%
df3.head()
# Out:
#   WHO region  Year Number of deaths due to HIV/AIDS
# 0     Global  2019                         690 000
# 1     Global  2018                         730 000
# 2     Global  2017                         760 000
# 3     Global  2016                         800 000
# 4     Global  2015                         830 000

# %%
df3.tail(31)
# Out:
#                 WHO region  Year Number of deaths due to HIV/AIDS
# 179  Eastern Mediterranean  1990                         &lt;500
# 180        Western Pacific  2019                          41 000
# 181        Western Pacific  2018                          42 000
# 182        Western Pacific  2017                          44 000
# 183        Western Pacific  2016                          45 000
# 184        Western Pacific  2015                          49 000
# 185        Western Pacific  2014                          52 000
# 186        Western Pacific  2013                          55 000
# 187        Western Pacific  2012                          59 000
# 188        Western Pacific  2011                          63 000
# 189        Western Pacific  2010                          64 000
# 190        Western Pacific  2009                          64 000
# 191        Western Pacific  2008                          65 000
# ...

# %%
df3['Number of deaths due to HIV/AIDS']=df3['Number of deaths due to HIV/AIDS'].str.replace(" ","")

# %%
df3.tail(31)
# Out:
#                 WHO region  Year Number of deaths due to HIV/AIDS
# 179  Eastern Mediterranean  1990                          &lt;500
# 180        Western Pacific  2019                            41000
# 181        Western Pacific  2018                            42000
# 182        Western Pacific  2017                            44000
# 183        Western Pacific  2016                            45000
# 184        Western Pacific  2015                            49000
# 185        Western Pacific  2014                            52000
# 186        Western Pacific  2013                            55000
# 187        Western Pacific  2012                            59000
# 188        Western Pacific  2011                            63000
# 189        Western Pacific  2010                            64000
# 190        Western Pacific  2009                            64000
# 191        Western Pacific  2008                            65000
# ...

# %%
df3['Number of deaths due to HIV/AIDS']=df3['Number of deaths due to HIV/AIDS'].str.replace('&lt;','')

# %%
df3.tail(31)
# Out:
#                 WHO region  Year Number of deaths due to HIV/AIDS
# 179  Eastern Mediterranean  1990                              500
# 180        Western Pacific  2019                            41000
# 181        Western Pacific  2018                            42000
# 182        Western Pacific  2017                            44000
# 183        Western Pacific  2016                            45000
# 184        Western Pacific  2015                            49000
# 185        Western Pacific  2014                            52000
# 186        Western Pacific  2013                            55000
# 187        Western Pacific  2012                            59000
# 188        Western Pacific  2011                            63000
# 189        Western Pacific  2010                            64000
# 190        Western Pacific  2009                            64000
# 191        Western Pacific  2008                            65000
# ...

# %%
df3["Number of deaths due to HIV/AIDS"] = pd.to_numeric(df3["Number of deaths due to HIV/AIDS"], downcast="float")

# %%
df3.head()
# Out:
#   WHO region  Year  Number of deaths due to HIV/AIDS
# 0     Global  2019                          690000.0
# 1     Global  2018                          730000.0
# 2     Global  2017                          760000.0
# 3     Global  2016                          800000.0
# 4     Global  2015                          830000.0

# %%
df.head()
# Out:
#                  Number of new HIV infections  \
# WHO region Year                           NaN
# Global     2019                     1700000.0
#            2018                     1700000.0
#            2017                     1800000.0
#            2016                     1800000.0
#
#                 New HIV infections (per 1000 uninfected population)  \
# WHO region Year                                         Both sexes
# Global     2019                                              0.22
#            2018                                              0.23
#            2017                                              0.24
#            2016                                              0.25
#
#                 New HIV infections (per 1000 uninfected population).1  \
# WHO region Year                                               Male
# Global     2019                                              0.23
#            2018                                              0.24
# ...

# %%
writer=pd.ExcelWriter("multiple.xlsx",engine="xlsxwriter")

# %%
df.to_excel(writer, sheet_name='Sheeta')

# %%
df3.to_excel(writer, sheet_name='Sheetb')

# %%
df2.to_excel(writer,sheet_name='sheetc')

# %%
writer.save()
